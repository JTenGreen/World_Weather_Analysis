# %%
#Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from citipy import citipy

# %%
#Create 2,000 random sets of latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 743

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
#Import dependencies

from citipy import citipy
from config import weather_api_key

import requests


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | beringovskiy
# Processing Record 2 of Set 1 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | saint andrews
# Processing Record 11 of Set 1 | mamit
# Processing Record 12 of Set 1 | tessalit
# Processing Record 13 of Set 1 | sydney
# Processing Record 14 of Set 1 | half moon bay
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | nome
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | moron
# Processing Record 19 of Set 1 | oriximina
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | batticaloa
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | tevaitoa
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | pacifica
# Processing Record 34 of Set 1 | jaguarari
# Processing Record 35 of Set 1 | winslow
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | emerald
# Processing Record 41 of Set 1 | waingapu
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | muzquiz
# City not found. Skipping...
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | taua
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | monrovia
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | itoman
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | shirokiy
# Processing Record 5 of Set 2 | la ronge
# Processing Record 6 of Set 2 | bandar-e lengeh
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | aksarka
# Processing Record 9 of Set 2 | ugoofaaru
# Processing Record 10 of Set 2 | omboue
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | san quintin
# Processing Record 13 of Set 2 | mulchen
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | vila velha
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | anantapur
# Processing Record 18 of Set 2 | nishihara
# Processing Record 19 of Set 2 | eyl
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | pokhara
# Processing Record 22 of Set 2 | dingle
# Processing Record 23 of Set 2 | mama
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | mount gambier
# Processing Record 26 of Set 2 | evensk
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | husavik
# Processing Record 30 of Set 2 | gorontalo
# Processing Record 31 of Set 2 | mayna
# Processing Record 32 of Set 2 | aranos
# Processing Record 33 of Set 2 | yumen
# Processing Record 34 of Set 2 | beatrice
# Processing Record 35 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 2 | port blair
# Processing Record 37 of Set 2 | yeniseysk
# Processing Record 38 of Set 2 | othonoi
# City not found. Skipping...
# Processing Record 39 of Set 2 | mumford
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | thinadhoo
# Processing Record 42 of Set 2 | alakurtti
# Processing Record 43 of Set 2 | berlevag
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | meulaboh
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | alofi
# Processing Record 48 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 2 | saint-joseph
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | akhnur
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | kenora
# Processing Record 4 of Set 3 | guarapuava
# Processing Record 5 of Set 3 | tromso
# Processing Record 6 of Set 3 | okhotsk
# Processing Record 7 of Set 3 | kahului
# Processing Record 8 of Set 3 | bilma
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | dalvik
# Processing Record 13 of Set 3 | whitecourt
# Processing Record 14 of Set 3 | flinders
# Processing Record 15 of Set 3 | borinskoye
# Processing Record 16 of Set 3 | strezhevoy
# Processing Record 17 of Set 3 | nuuk
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | riyadh
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | katobu
# Processing Record 22 of Set 3 | saint-pierre
# Processing Record 23 of Set 3 | mont-dore
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 3 | kidal
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | san cristobal
# Processing Record 30 of Set 3 | huarmey
# Processing Record 31 of Set 3 | tobermory
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | ucluelet
# Processing Record 34 of Set 3 | kadarkut
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | pitelino
# Processing Record 37 of Set 3 | inhambane
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | pacific grove
# Processing Record 42 of Set 3 | taunggyi
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | hamilton
# Processing Record 45 of Set 3 | rawson
# Processing Record 46 of Set 3 | caririacu
# Processing Record 47 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | saint-raymond
# Processing Record 1 of Set 4 | cayenne
# Processing Record 2 of Set 4 | saint-augustin
# Processing Record 3 of Set 4 | herat
# Processing Record 4 of Set 4 | den helder
# Processing Record 5 of Set 4 | asfi
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | mucuri
# Processing Record 9 of Set 4 | ambilobe
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | samarai
# Processing Record 12 of Set 4 | camopi
# Processing Record 13 of Set 4 | adamovka
# Processing Record 14 of Set 4 | heyang
# Processing Record 15 of Set 4 | moranbah
# Processing Record 16 of Set 4 | khorinsk
# Processing Record 17 of Set 4 | buluang
# Processing Record 18 of Set 4 | tuktoyaktuk
# Processing Record 19 of Set 4 | bela
# Processing Record 20 of Set 4 | coihaique
# Processing Record 21 of Set 4 | morant bay
# Processing Record 22 of Set 4 | altay
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | halifax
# Processing Record 25 of Set 4 | abu dhabi
# Processing Record 26 of Set 4 | matagami
# Processing Record 27 of Set 4 | yeppoon
# Processing Record 28 of Set 4 | alice springs
# Processing Record 29 of Set 4 | havoysund
# Processing Record 30 of Set 4 | pahrump
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | port macquarie
# Processing Record 33 of Set 4 | tucurui
# Processing Record 34 of Set 4 | hofn
# Processing Record 35 of Set 4 | tilichiki
# Processing Record 36 of Set 4 | sitka
# Processing Record 37 of Set 4 | nikolskoye
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | qinzhou
# Processing Record 40 of Set 4 | bara
# Processing Record 41 of Set 4 | dunedin
# Processing Record 42 of Set 4 | pangody
# Processing Record 43 of Set 4 | gazli
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | tuatapere
# Processing Record 46 of Set 4 | kampong chhnang
# Processing Record 47 of Set 4 | phnum penh
# City not found. Skipping...
# Processing Record 48 of Set 4 | kanigoro
# Processing Record 49 of Set 4 | buraydah
# Processing Record 50 of Set 4 | muleba
# Processing Record 1 of Set 5 | soyo
# Processing Record 2 of Set 5 | saint-philippe
# Processing Record 3 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 4 of Set 5 | humaita
# Processing Record 5 of Set 5 | mitsamiouli
# Processing Record 6 of Set 5 | udachnyy
# Processing Record 7 of Set 5 | pinar del rio
# Processing Record 8 of Set 5 | port hardy
# Processing Record 9 of Set 5 | isangel
# Processing Record 10 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 11 of Set 5 | takoradi
# Processing Record 12 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 13 of Set 5 | glace bay
# Processing Record 14 of Set 5 | san-pedro
# Processing Record 15 of Set 5 | grindavik
# Processing Record 16 of Set 5 | maldonado
# Processing Record 17 of Set 5 | nyagan
# Processing Record 18 of Set 5 | menongue
# Processing Record 19 of Set 5 | egvekinot
# Processing Record 20 of Set 5 | lang son
# Processing Record 21 of Set 5 | rio grande
# Processing Record 22 of Set 5 | ayan
# Processing Record 23 of Set 5 | general roca
# Processing Record 24 of Set 5 | vila
# Processing Record 25 of Set 5 | port moresby
# Processing Record 26 of Set 5 | khipro
# Processing Record 27 of Set 5 | turukhansk
# Processing Record 28 of Set 5 | lander
# Processing Record 29 of Set 5 | jizan
# Processing Record 30 of Set 5 | broken hill
# Processing Record 31 of Set 5 | sharkan
# Processing Record 32 of Set 5 | inirida
# Processing Record 33 of Set 5 | altamira
# Processing Record 34 of Set 5 | iqaluit
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | altona
# Processing Record 37 of Set 5 | port shepstone
# Processing Record 38 of Set 5 | burica
# City not found. Skipping...
# Processing Record 39 of Set 5 | sweetwater
# Processing Record 40 of Set 5 | vardo
# Processing Record 41 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | sorland
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | landeck
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | lata
# Processing Record 48 of Set 5 | high prairie
# Processing Record 49 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 5 | sisimiut
# Processing Record 1 of Set 6 | kuusamo
# Processing Record 2 of Set 6 | senador pompeu
# Processing Record 3 of Set 6 | palmer
# Processing Record 4 of Set 6 | bijie
# Processing Record 5 of Set 6 | bonavista
# Processing Record 6 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 7 of Set 6 | jacareacanga
# Processing Record 8 of Set 6 | klyuchi
# Processing Record 9 of Set 6 | namatanai
# Processing Record 10 of Set 6 | lasa
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | allen
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | sept-iles
# Processing Record 15 of Set 6 | priyutnoye
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | souillac
# Processing Record 18 of Set 6 | north bend
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | cheremukhovo
# Processing Record 21 of Set 6 | saiha
# Processing Record 22 of Set 6 | severo-kurilsk
# Processing Record 23 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 6 | tahta
# Processing Record 25 of Set 6 | baijiantan
# Processing Record 26 of Set 6 | vestmannaeyjar
# Processing Record 27 of Set 6 | aripuana
# Processing Record 28 of Set 6 | venice
# Processing Record 29 of Set 6 | puertollano
# Processing Record 30 of Set 6 | bereda
# Processing Record 31 of Set 6 | gat
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | guerrero negro
# Processing Record 34 of Set 6 | cassia
# Processing Record 35 of Set 6 | umm bab
# Processing Record 36 of Set 6 | myanaung
# Processing Record 37 of Set 6 | bonthe
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | sansai
# City not found. Skipping...
# Processing Record 40 of Set 6 | coquimbo
# Processing Record 41 of Set 6 | stabroek
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | musiri
# Processing Record 44 of Set 6 | caravelas
# Processing Record 45 of Set 6 | najran
# Processing Record 46 of Set 6 | faanui
# Processing Record 47 of Set 6 | sazonovo
# Processing Record 48 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 6 | strelka
# Processing Record 50 of Set 6 | carnarvon
# Processing Record 1 of Set 7 | semirom
# Processing Record 2 of Set 7 | soe
# Processing Record 3 of Set 7 | bodden town
# Processing Record 4 of Set 7 | paamiut
# Processing Record 5 of Set 7 | gizo
# Processing Record 6 of Set 7 | shieli
# Processing Record 7 of Set 7 | ponta do sol
# Processing Record 8 of Set 7 | waipawa
# Processing Record 9 of Set 7 | san patricio
# Processing Record 10 of Set 7 | nador
# Processing Record 11 of Set 7 | vostok
# Processing Record 12 of Set 7 | lavrentiya
# Processing Record 13 of Set 7 | itarema
# Processing Record 14 of Set 7 | merauke
# Processing Record 15 of Set 7 | jumla
# Processing Record 16 of Set 7 | craig
# Processing Record 17 of Set 7 | surt
# Processing Record 18 of Set 7 | kodiak
# Processing Record 19 of Set 7 | wellington
# Processing Record 20 of Set 7 | taksimo
# Processing Record 21 of Set 7 | miandrivazo
# Processing Record 22 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 7 | sakharovo
# Processing Record 24 of Set 7 | oreanda
# City not found. Skipping...
# Processing Record 25 of Set 7 | margate
# Processing Record 26 of Set 7 | talnakh
# Processing Record 27 of Set 7 | beaverlodge
# Processing Record 28 of Set 7 | faya
# Processing Record 29 of Set 7 | micheweni
# Processing Record 30 of Set 7 | primo tapia
# Processing Record 31 of Set 7 | isla vista
# Processing Record 32 of Set 7 | mandera
# Processing Record 33 of Set 7 | siemiatycze
# Processing Record 34 of Set 7 | lagoa
# Processing Record 35 of Set 7 | buzmeyin
# Processing Record 36 of Set 7 | vidim
# Processing Record 37 of Set 7 | chuy
# Processing Record 38 of Set 7 | bajil
# Processing Record 39 of Set 7 | rio gallegos
# Processing Record 40 of Set 7 | madawaska
# Processing Record 41 of Set 7 | lorengau
# Processing Record 42 of Set 7 | mogadishu
# Processing Record 43 of Set 7 | vangaindrano
# Processing Record 44 of Set 7 | asyut
# Processing Record 45 of Set 7 | ocos
# Processing Record 46 of Set 7 | rabo de peixe
# Processing Record 47 of Set 7 | sipe sipe
# Processing Record 48 of Set 7 | illela
# Processing Record 49 of Set 7 | santa isabel
# Processing Record 50 of Set 7 | atambua
# Processing Record 1 of Set 8 | saldanha
# Processing Record 2 of Set 8 | krasnoselkup
# Processing Record 3 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 8 | temyasovo
# Processing Record 5 of Set 8 | ariogala
# Processing Record 6 of Set 8 | sambava
# Processing Record 7 of Set 8 | aktash
# Processing Record 8 of Set 8 | the valley
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | roma
# Processing Record 11 of Set 8 | mount isa
# Processing Record 12 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 8 | mirnyy
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | lagos
# Processing Record 16 of Set 8 | tutoia
# Processing Record 17 of Set 8 | fenoarivo
# Processing Record 18 of Set 8 | vao
# Processing Record 19 of Set 8 | muros
# Processing Record 20 of Set 8 | kaeo
# Processing Record 21 of Set 8 | bud
# Processing Record 22 of Set 8 | delicioso
# Processing Record 23 of Set 8 | gubkinskiy
# Processing Record 24 of Set 8 | wanning
# Processing Record 25 of Set 8 | sao felix do xingu
# Processing Record 26 of Set 8 | oksfjord
# Processing Record 27 of Set 8 | madang
# Processing Record 28 of Set 8 | nanfeng
# Processing Record 29 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 30 of Set 8 | ust-ilimsk
# Processing Record 31 of Set 8 | novyy urgal
# Processing Record 32 of Set 8 | haysville
# Processing Record 33 of Set 8 | haljala
# Processing Record 34 of Set 8 | jibuti
# Processing Record 35 of Set 8 | safaga
# Processing Record 36 of Set 8 | stephenville
# Processing Record 37 of Set 8 | ambovombe
# Processing Record 38 of Set 8 | biggar
# Processing Record 39 of Set 8 | plouzane
# Processing Record 40 of Set 8 | srednekolymsk
# Processing Record 41 of Set 8 | kavaratti
# Processing Record 42 of Set 8 | betare oya
# Processing Record 43 of Set 8 | chitradurga
# Processing Record 44 of Set 8 | colac
# Processing Record 45 of Set 8 | teneguiban
# City not found. Skipping...
# Processing Record 46 of Set 8 | krasnyy chikoy
# Processing Record 47 of Set 8 | sao miguel do araguaia
# Processing Record 48 of Set 8 | winnemucca
# Processing Record 49 of Set 8 | enzan
# Processing Record 50 of Set 8 | tshikapa
# Processing Record 1 of Set 9 | carutapera
# Processing Record 2 of Set 9 | kapitanivka
# Processing Record 3 of Set 9 | skjervoy
# Processing Record 4 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 5 of Set 9 | chumikan
# Processing Record 6 of Set 9 | upington
# Processing Record 7 of Set 9 | tabou
# Processing Record 8 of Set 9 | am timan
# Processing Record 9 of Set 9 | culpeper
# Processing Record 10 of Set 9 | siauliai
# Processing Record 11 of Set 9 | ahipara
# Processing Record 12 of Set 9 | tongchuan
# Processing Record 13 of Set 9 | pingliang
# Processing Record 14 of Set 9 | mazagao
# Processing Record 15 of Set 9 | marquette
# Processing Record 16 of Set 9 | bursol
# City not found. Skipping...
# Processing Record 17 of Set 9 | boguchany
# Processing Record 18 of Set 9 | villarrica
# Processing Record 19 of Set 9 | wajima
# Processing Record 20 of Set 9 | ola
# Processing Record 21 of Set 9 | zhigansk
# Processing Record 22 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 23 of Set 9 | bjerkvik
# Processing Record 24 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 9 | akdepe
# Processing Record 27 of Set 9 | myitkyina
# Processing Record 28 of Set 9 | cam ranh
# Processing Record 29 of Set 9 | arawa
# Processing Record 30 of Set 9 | kushikino
# Processing Record 31 of Set 9 | uk
# City not found. Skipping...
# Processing Record 32 of Set 9 | alugan
# Processing Record 33 of Set 9 | esperance
# Processing Record 34 of Set 9 | akureyri
# Processing Record 35 of Set 9 | hvide sande
# Processing Record 36 of Set 9 | pyaozerskiy
# Processing Record 37 of Set 9 | bekhtery
# Processing Record 38 of Set 9 | bull savanna
# Processing Record 39 of Set 9 | portland
# Processing Record 40 of Set 9 | erenhot
# Processing Record 41 of Set 9 | bukama
# Processing Record 42 of Set 9 | saint anthony
# Processing Record 43 of Set 9 | usolye
# Processing Record 44 of Set 9 | sabang
# Processing Record 45 of Set 9 | kutum
# Processing Record 46 of Set 9 | olafsvik
# Processing Record 47 of Set 9 | harper
# Processing Record 48 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 49 of Set 9 | ekibastuz
# Processing Record 50 of Set 9 | trelew
# Processing Record 1 of Set 10 | pingzhuang
# Processing Record 2 of Set 10 | aswan
# Processing Record 3 of Set 10 | codrington
# Processing Record 4 of Set 10 | shingu
# Processing Record 5 of Set 10 | mahibadhoo
# Processing Record 6 of Set 10 | balkanabat
# Processing Record 7 of Set 10 | madrid
# Processing Record 8 of Set 10 | victor harbor
# Processing Record 9 of Set 10 | kaoma
# Processing Record 10 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 11 of Set 10 | cherskiy
# Processing Record 12 of Set 10 | ouallam
# Processing Record 13 of Set 10 | imbituba
# Processing Record 14 of Set 10 | mago
# Processing Record 15 of Set 10 | joao pinheiro
# Processing Record 16 of Set 10 | fukue
# Processing Record 17 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 10 | salisbury
# Processing Record 19 of Set 10 | komsomolskiy
# Processing Record 20 of Set 10 | mwense
# Processing Record 21 of Set 10 | celestun
# Processing Record 22 of Set 10 | oktyabrskoye
# Processing Record 23 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 10 | ust-nera
# Processing Record 25 of Set 10 | katsuura
# Processing Record 26 of Set 10 | anadyr
# Processing Record 27 of Set 10 | kumylzhenskaya
# Processing Record 28 of Set 10 | coelho neto
# Processing Record 29 of Set 10 | baculin
# Processing Record 30 of Set 10 | kihei
# Processing Record 31 of Set 10 | samoded
# Processing Record 32 of Set 10 | port lincoln
# Processing Record 33 of Set 10 | beasain
# Processing Record 34 of Set 10 | kandrian
# Processing Record 35 of Set 10 | naze
# Processing Record 36 of Set 10 | sterling
# Processing Record 37 of Set 10 | chillan
# Processing Record 38 of Set 10 | hualmay
# Processing Record 39 of Set 10 | shenzhen
# Processing Record 40 of Set 10 | whitehorse
# Processing Record 41 of Set 10 | dori
# Processing Record 42 of Set 10 | vorobyevka
# Processing Record 43 of Set 10 | zeya
# Processing Record 44 of Set 10 | mecca
# Processing Record 45 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 46 of Set 10 | qasigiannguit
# Processing Record 47 of Set 10 | chisec
# Processing Record 48 of Set 10 | vila franca do campo
# Processing Record 49 of Set 10 | mersing
# Processing Record 50 of Set 10 | grand gaube
# Processing Record 1 of Set 11 | marystown
# Processing Record 2 of Set 11 | marsh harbour
# Processing Record 3 of Set 11 | tsabong
# Processing Record 4 of Set 11 | severnyy
# Processing Record 5 of Set 11 | nizwa
# Processing Record 6 of Set 11 | sorong
# Processing Record 7 of Set 11 | monte cristi
# City not found. Skipping...
# Processing Record 8 of Set 11 | karratha
# Processing Record 9 of Set 11 | dombas
# Processing Record 10 of Set 11 | road town
# Processing Record 11 of Set 11 | beitbridge
# Processing Record 12 of Set 11 | kulhudhuffushi
# Processing Record 13 of Set 11 | jega
# Processing Record 14 of Set 11 | iquique
# Processing Record 15 of Set 11 | birin
# Processing Record 16 of Set 11 | nanortalik
# Processing Record 17 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 19 of Set 11 | spencer
# Processing Record 20 of Set 11 | perevolotskiy
# Processing Record 21 of Set 11 | kot samaba
# Processing Record 22 of Set 11 | macklin
# Processing Record 23 of Set 11 | tamiahua
# Processing Record 24 of Set 11 | ossora
# Processing Record 25 of Set 11 | buin
# Processing Record 26 of Set 11 | porto novo
# Processing Record 27 of Set 11 | northam
# Processing Record 28 of Set 11 | tehachapi
# Processing Record 29 of Set 11 | dakoro
# Processing Record 30 of Set 11 | sao joao da barra
# Processing Record 31 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 11 | peterhead
# Processing Record 33 of Set 11 | aviles
# Processing Record 34 of Set 11 | iracoubo
# Processing Record 35 of Set 11 | looc
# Processing Record 36 of Set 11 | oxford
# Processing Record 37 of Set 11 | batagay-alyta
# Processing Record 38 of Set 11 | muncar
# Processing Record 39 of Set 11 | hambantota
# Processing Record 40 of Set 11 | sohagpur
# Processing Record 41 of Set 11 | nantucket
# Processing Record 42 of Set 11 | kushmurun
# Processing Record 43 of Set 11 | sao raimundo das mangabeiras
# Processing Record 44 of Set 11 | mizdah
# Processing Record 45 of Set 11 | watertown
# Processing Record 46 of Set 11 | esfarayen
# Processing Record 47 of Set 11 | hopelchen
# Processing Record 48 of Set 11 | ostrovnoy
# Processing Record 49 of Set 11 | constantine
# Processing Record 50 of Set 11 | carauari
# Processing Record 1 of Set 12 | horadiz
# Processing Record 2 of Set 12 | leh
# Processing Record 3 of Set 12 | hita
# Processing Record 4 of Set 12 | muscat
# Processing Record 5 of Set 12 | khandyga
# Processing Record 6 of Set 12 | sibolga
# Processing Record 7 of Set 12 | lianran
# Processing Record 8 of Set 12 | kibala
# Processing Record 9 of Set 12 | fonte boa
# Processing Record 10 of Set 12 | balabac
# Processing Record 11 of Set 12 | alyangula
# Processing Record 12 of Set 12 | kingaroy
# Processing Record 13 of Set 12 | coahuayana
# Processing Record 14 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 12 | baykit
# Processing Record 16 of Set 12 | malaut
# Processing Record 17 of Set 12 | bilibino
# Processing Record 18 of Set 12 | warmbad
# Processing Record 19 of Set 12 | padang
# Processing Record 20 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 12 | khuzdar
# Processing Record 22 of Set 12 | boa vista
# Processing Record 23 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 12 | jalu
# Processing Record 25 of Set 12 | belaya gora
# Processing Record 26 of Set 12 | mudgee
# Processing Record 27 of Set 12 | yelizovo
# Processing Record 28 of Set 12 | pasighat
# Processing Record 29 of Set 12 | constitucion
# Processing Record 30 of Set 12 | cabo san lucas
# Processing Record 31 of Set 12 | angoche
# Processing Record 32 of Set 12 | chapais
# Processing Record 33 of Set 12 | atar
# Processing Record 34 of Set 12 | buala
# Processing Record 35 of Set 12 | aykhal
# Processing Record 36 of Set 12 | roberval
# Processing Record 37 of Set 12 | luanda
# Processing Record 38 of Set 12 | chegdomyn
# Processing Record 39 of Set 12 | yanam
# Processing Record 40 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 12 | verkhnevilyuysk
# Processing Record 42 of Set 12 | shenjiamen
# Processing Record 43 of Set 12 | hadgaon
# Processing Record 44 of Set 12 | samatau
# City not found. Skipping...
# Processing Record 45 of Set 12 | sivaki
# Processing Record 46 of Set 12 | niteroi
# Processing Record 47 of Set 12 | singapore
# Processing Record 48 of Set 12 | kwinana
# Processing Record 49 of Set 12 | bayanday
# Processing Record 50 of Set 12 | garden city
# Processing Record 1 of Set 13 | richards bay
# Processing Record 2 of Set 13 | jhargram
# Processing Record 3 of Set 13 | riachao das neves
# Processing Record 4 of Set 13 | chom bung
# City not found. Skipping...
# Processing Record 5 of Set 13 | acopiara
# Processing Record 6 of Set 13 | lokosovo
# Processing Record 7 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 8 of Set 13 | iralaya
# Processing Record 9 of Set 13 | cairns
# Processing Record 10 of Set 13 | smithers
# Processing Record 11 of Set 13 | porto belo
# Processing Record 12 of Set 13 | palana
# Processing Record 13 of Set 13 | ambulu
# Processing Record 14 of Set 13 | svecha
# Processing Record 15 of Set 13 | pouebo
# Processing Record 16 of Set 13 | tarko-sale
# Processing Record 17 of Set 13 | jaisalmer
# Processing Record 18 of Set 13 | kargasok
# Processing Record 19 of Set 13 | lompoc
# Processing Record 20 of Set 13 | klichka
# Processing Record 21 of Set 13 | iowa city
# Processing Record 22 of Set 13 | kupang
# Processing Record 23 of Set 13 | thio
# Processing Record 24 of Set 13 | sioux lookout
# Processing Record 25 of Set 13 | honningsvag
# Processing Record 26 of Set 13 | ilo
# Processing Record 27 of Set 13 | qaqortoq
# Processing Record 28 of Set 13 | belmonte
# Processing Record 29 of Set 13 | avare
# Processing Record 30 of Set 13 | pastos bons
# Processing Record 31 of Set 13 | singaraja
# Processing Record 32 of Set 13 | platteville
# Processing Record 33 of Set 13 | vieste
# Processing Record 34 of Set 13 | kashary
# Processing Record 35 of Set 13 | banepa
# Processing Record 36 of Set 13 | tome-acu
# City not found. Skipping...
# Processing Record 37 of Set 13 | champerico
# Processing Record 38 of Set 13 | valley city
# Processing Record 39 of Set 13 | leshukonskoye
# Processing Record 40 of Set 13 | adrar
# Processing Record 41 of Set 13 | gacheta
# Processing Record 42 of Set 13 | hobyo
# Processing Record 43 of Set 13 | jiwani
# Processing Record 44 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 13 | diego de almagro
# Processing Record 46 of Set 13 | san bartolome de tirajana
# Processing Record 47 of Set 13 | phan thiet
# Processing Record 48 of Set 13 | kenai
# Processing Record 49 of Set 13 | hoshangabad
# Processing Record 50 of Set 13 | kautokeino
# Processing Record 1 of Set 14 | oga
# Processing Record 2 of Set 14 | shepsi
# Processing Record 3 of Set 14 | manado
# Processing Record 4 of Set 14 | pizarro
# Processing Record 5 of Set 14 | antalaha
# Processing Record 6 of Set 14 | calama
# Processing Record 7 of Set 14 | marau
# Processing Record 8 of Set 14 | safranbolu
# Processing Record 9 of Set 14 | itaituba
# Processing Record 10 of Set 14 | kungurtug
# Processing Record 11 of Set 14 | bathsheba
# Processing Record 12 of Set 14 | dumai
# Processing Record 13 of Set 14 | pochutla
# Processing Record 14 of Set 14 | svetlyy
# Processing Record 15 of Set 14 | tadine
# Processing Record 16 of Set 14 | kruisfontein
# Processing Record 17 of Set 14 | sakakah
# Processing Record 18 of Set 14 | acapulco
# Processing Record 19 of Set 14 | stornoway
# Processing Record 20 of Set 14 | dalbandin
# Processing Record 21 of Set 14 | bulawayo
# Processing Record 22 of Set 14 | bay roberts
# Processing Record 23 of Set 14 | torrington
# Processing Record 24 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 14 | nouadhibou
# Processing Record 26 of Set 14 | pombas
# Processing Record 27 of Set 14 | corinto
# Processing Record 28 of Set 14 | kandava
# Processing Record 29 of Set 14 | shache
# Processing Record 30 of Set 14 | uige
# Processing Record 31 of Set 14 | malanje
# Processing Record 32 of Set 14 | hovd
# Processing Record 33 of Set 14 | kodinsk
# Processing Record 34 of Set 14 | opuwo
# Processing Record 35 of Set 14 | tallahassee
# Processing Record 36 of Set 14 | arrifes
# Processing Record 37 of Set 14 | jaque
# Processing Record 38 of Set 14 | osoyoos
# Processing Record 39 of Set 14 | clyde river
# Processing Record 40 of Set 14 | sovetsk
# Processing Record 41 of Set 14 | saint-francois
# Processing Record 42 of Set 14 | sangre grande
# Processing Record 43 of Set 14 | newport
# Processing Record 44 of Set 14 | acarau
# Processing Record 45 of Set 14 | dukat
# Processing Record 46 of Set 14 | nurobod
# Processing Record 47 of Set 14 | hirado
# Processing Record 48 of Set 14 | ternate
# Processing Record 49 of Set 14 | kimbe
# Processing Record 50 of Set 14 | araouane
# Processing Record 1 of Set 15 | cabedelo
# Processing Record 2 of Set 15 | pavlivka
# Processing Record 3 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 4 of Set 15 | seymchan
# Processing Record 5 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 15 | makakilo city
# Processing Record 7 of Set 15 | yerbogachen
# Processing Record 8 of Set 15 | mercedes
# Processing Record 9 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 15 | la crosse
# Processing Record 11 of Set 15 | robinson
# Processing Record 12 of Set 15 | rock sound
# Processing Record 13 of Set 15 | haukipudas
# Processing Record 14 of Set 15 | satna
# Processing Record 15 of Set 15 | kurilsk
# Processing Record 16 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 15 | rudbar
# Processing Record 18 of Set 15 | guiratinga
# Processing Record 19 of Set 15 | praia
# Processing Record 20 of Set 15 | benguela
# Processing Record 21 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 22 of Set 15 | dickinson
# Processing Record 23 of Set 15 | mehamn
# Processing Record 24 of Set 15 | san juan
# Processing Record 25 of Set 15 | keelung
# Processing Record 26 of Set 15 | tautira
# Processing Record 27 of Set 15 | bhim tal
# Processing Record 28 of Set 15 | nizhniy ingash
# Processing Record 29 of Set 15 | port augusta
# Processing Record 30 of Set 15 | puerto colombia
# Processing Record 31 of Set 15 | mokhsogollokh
# Processing Record 32 of Set 15 | grand-santi
# Processing Record 33 of Set 15 | namtsy
# Processing Record 34 of Set 15 | zaporizhzhya
# Processing Record 35 of Set 15 | haimen
# Processing Record 36 of Set 15 | bairiki
# Processing Record 37 of Set 15 | helong
# Processing Record 38 of Set 15 | hay river
# Processing Record 39 of Set 15 | saint pete beach
# Processing Record 40 of Set 15 | storsteinnes
# Processing Record 41 of Set 15 | hereford
# Processing Record 42 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 15 | juba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Beringovskiy      RU  63.0500  179.3167     45.09        70         100
# 1        Kavieng      PG  -2.5744  150.7967     82.58        77          46
# 2       Tasiilaq      GL  65.6145  -37.6368     44.76        72         100
# 3    Yellowknife      CA  62.4560 -114.3525     81.12        39          75
# 4      Saskylakh      RU  71.9167  114.0833     46.04        91          93
# 5         Atuona      PF  -9.8000 -139.0333     76.57        79          13
# 6        Mataura      NZ -46.1927  168.8643     52.00        91          84
# 7   Longyearbyen      SJ  78.2186   15.6401     38.71        98         100
# 8  Saint Andrews      US  34.0454  -81.1293     75.29        70          75
# 9          Mamit      IN  23.9333   92.4833     69.64        93          65
#
#    Wind Speed Current Description
# 0       13.40     overcast clouds
# 1       12.24          light rain
# 2       11.68     overcast clouds
# 3        6.91       broken clouds
# 4        8.77     overcast clouds
# 5       19.42          light rain
# 6        2.66       broken clouds
# 7       11.41          light rain
# 8        9.22       broken clouds
# 9        1.83       broken clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3156\3782751744.py in <module>
#       1 output_data_file = "Weather_Database/WeatherPy_Database.csv"
# ----> 2 city_data_df.to_csv(output_data_file, index_label='City_ID')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
